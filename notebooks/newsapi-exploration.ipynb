# %% [markdown]
# # News API Exploration
# A crucial part in the steps for this project is finding methods for aquiring adequate amounts of news data that is both specific and localized. This following notebook will show the exploration of several different chosen news API.

# %%
from newsapi import NewsApiClient

# %%
newsapi = NewsApiClient(api_key='576af9dfe5ea45f996eda1df5bde0cd0')

# %%
top_headlines = newsapi.get_top_headlines(q='nashville',
                                          language='en')

# %%
print(top_headlines)
# Out:
# {'status': 'ok', 'totalResults': 0, 'articles': []}

# %%
everything_test = newsapi.get_everything(q="nashville",
                                         language="en")

# %%
print(everything_test)
# Out:
# {'status': 'ok', 'totalResults': 2586, 'articles': [{'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'Cork Gaines', 'title': "Why people are flocking to these 10 'blue island' cities", 'description': 'Blue cities in red states are attractive to workers due to the lifestyle and high-paying jobs.', 'url': 'https://www.businessinsider.com/blue-cities-red-states-tech-companies-austin-nashville-las-vegas-2023-12', 'urlToImage': 'https://i.insider.com/65848efb1c5c7b8c9a0b3bbb?width=1200&format=jpeg', 'publishedAt': '2024-01-05T11:03:01Z', 'content': 'Nashville is one of the blue island cities going through a population boom.TriggerPhoto/Getty Images\r\n<ul><li>Blue cities in red states, dubbed "blue islands," are attractive to workers due to the jo… [+5228 chars]'}, {'source': {'id': 'business-insider', 'name': 'Business Insider'}, 'author': 'Jen Glantz', 'title': "I'm a Nashville local. It's expensive and overrun by tourists, but it's still the best city in the
# ...

# %%
nashville_opioid = newsapi.get_everything(q="nashville opioid",
                                          language="en")

# %%
print(nashville_opioid)
# Out:
# {'status': 'ok', 'totalResults': 1, 'articles': [{'source': {'id': 'fox-news', 'name': 'Fox News'}, 'author': 'Michael Dorgan', 'title': 'Tennessee father charged in death of 23-month-old son who overdosed on fentanyl', 'description': 'A father from Tennessee has been charged with the death of his 23-month-old son who died after consuming synthetic opioids fentanyl and metonitazene while in his care.', 'url': 'https://www.foxnews.com/us/tennessee-father-charged-death-23-month-old-son-overdosed-fentanyl', 'urlToImage': 'https://static.foxnews.com/foxnews.com/content/uploads/2024/01/Kelvin-Blaylock-1.jpg', 'publishedAt': '2024-01-06T12:14:25Z', 'content': 'A Tennessee man has been charged with the death of his 23-month-old son who died in October from a fentanyl-related fatal overdose, the Metropolitan Nashville Police Department (MNPD) has announced.\r… [+1902 chars]'}]}

# %%
memphis_opioid = newsapi.get_everything(q="memphis opioid",
                                          language="en")

# %%
print(memphis_opioid)
# Out:
# {'status': 'ok', 'totalResults': 6, 'articles': [{'source': {'id': None, 'name': 'NPR'}, 'author': 'The Associated Press', 'title': "Newly released recordings reveal what officers said after Tyre Nichols' fatal beating", 'description': 'About 21 hours of newly released video and audio are revealing more about what first responders in Memphis, Tenn., did and said the night Nichols was pulled over and mortally injured.', 'url': 'https://www.npr.org/2024/01/31/1228146283/tyre-nichols-more-memphis-police-videos-released', 'urlToImage': 'https://media.npr.org/assets/img/2024/01/31/ap24030630326030_wide-203a08e1514f6b088c015a4226b5e2717895a131-s1400-c100.jpg', 'publishedAt': '2024-01-31T19:47:06Z', 'content': 'Candles spell out the name of Tyre Nichols during a candlelight vigil on the anniversary of his death, Jan. 7, 2024, in Memphis, Tenn.\r\nKaren Pulfer Focht/AP\r\nMEMPHIS, Tenn. About 21 hours of newly r… [+6585 chars]'}, {'source': {'id': 'nbc-news', 'name': 'NBC News'}, 'author': '
# ...

# %%
https://github.com/lewisdonovan/google-news-scraper
